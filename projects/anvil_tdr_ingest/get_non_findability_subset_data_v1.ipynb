# %%
# imports relevant packages. (Shift + Enter) to execute.

import ast
import os
import json
import re
from firecloud import api as fapi
import pandas as pd
from io import StringIO
import csv
import pprint
from collections import OrderedDict

import requests
from google.cloud import bigquery
from oauth2client.client import GoogleCredentials

# Sets up workspace environment variables. (Shift + Enter) to execute.

ws_project = os.environ['WORKSPACE_NAMESPACE']
ws_name = os.environ['WORKSPACE_NAME']
ws_bucket = os.environ['WORKSPACE_BUCKET']
google_project = os.environ['GOOGLE_PROJECT']

print(ws_project + "\n" + ws_name + "\n" + "bucket: " + ws_bucket + "\n" + "google project: " + google_project)
# Out:
# anvil-stage-demo
# internal_demo_AnVIL_Data_Browser_completed
# bucket: gs://fc-b9d72b57-5a36-46ff-967b-38098b2a1889
# google project: terra-bf174a68

# %%
# gets list of single entity types in workspace. (Shift + Enter) to execute.
    
# API call to get all entity types in workspace
res_etypes = fapi.list_entity_types(ws_project, ws_name)
dict_all_etypes = json.loads(res_etypes.text)

# get non-set entities and add to list
# the unique ID of any single entity is not modified so sets should remain the same
single_etypes_list = []
single_etypes_list = [key for key in dict_all_etypes.keys() if not key.endswith("_set")]

print(f"List of entity types that will be updated, if applicable:")
print('\n'.join(['\t' * 7 + c for c in single_etypes_list]))
# Out:
# List of entity types that will be updated, if applicable:
# 							activities
# 							donors
# 							files
# 							datasets
# 							biosamples

# %%
# functions. (Shift + Enter) to execute.
def get_access_token():
    """Get access token."""

    scopes = ["https://www.googleapis.com/auth/userinfo.profile", "https://www.googleapis.com/auth/userinfo.email", "openid"]
    credentials = GoogleCredentials.get_application_default()
    credentials = credentials.create_scoped(scopes)

    return credentials.get_access_token().access_token


def get_query_results(query):
    """Performs a BQ query."""
    
    # create BQ connection
    bq = bigquery.Client(google_project)
    
    executed_query = bq.query(query)
    result = executed_query.result()
    
    df_result = result.to_dataframe()
    
    return df_result


def get_dataset_info(dataset_id):
    """"Get dataset details from retrieveDataset API given a datasetID."""
    
    uri = f"https://data.terra.bio/api/repository/v1/datasets/{dataset_id}?include=SCHEMA%2CPROFILE%2CDATA_PROJECT%2CSTORAGE"
    
    headers = {"Authorization": "Bearer " + get_access_token(), "accept": "application/json"}
    
    response = requests.get(uri, headers=headers)
    status_code = response.status_code
    
    if status_code != 200:
        return response.text
    
    print(f"Successfully retrieved details for dataset with datasetID {dataset_id}.")
    return json.loads(response.text)


def get_snapshot_info(snapshot_id):
    """"Get dataset details from retrieveDataset API given a datasetID."""
    
    uri = f"https://data.terra.bio/api/repository/v1/snapshots/{snapshot_id}?include="

    headers = {"Authorization": "Bearer " + get_access_token(), "accept": "application/json"}
    
    response = requests.get(uri, headers=headers)
    status_code = response.status_code
    
    if status_code != 200:
        return response.text
    
    print(f"Successfully retrieved details for dataset with datasetID {snapshot_id}.")
    return json.loads(response.text)


def get_dataset_access_info(dataset_id):
    """"Get dataset access details from retrieveDataset API given a datasetID."""
    
    uri = f"https://data.terra.bio/api/repository/v1/datasets/{dataset_id}?include=ACCESS_INFORMATION"
    
    headers = {"Authorization": "Bearer " + get_access_token(),
               "accept": "application/json"}
    
    response = requests.get(uri, headers=headers)
    status_code = response.status_code
    
    if status_code != 200:
        return response.text
    
    print(f"Successfully retrieved access information for dataset with datasetID {dataset_id}.")
    return json.loads(response.text)


def get_snapshot_access_info(snapshot_id):
    """Get snapshot access information from retrieveSnapshot API given a snapshotID"""
    
    uri = f"https://data.terra.bio/api/repository/v1/snapshots/{snapshot_id}?include=ACCESS_INFORMATION"
    
    headers = {"Authorization": "Bearer " + get_access_token(),
               "accept": "application/json"}
    
    response = requests.get(uri, headers=headers)
    status_code = response.status_code
    
    if status_code != 200:
        return response.text
    
    print(f"Successfully retrieved access information for snapshot with snapshotID {snapshot_id}.")
    return json.loads(response.text)


def get_fq_table(entity_id, table_name, entity_type='dataset'):
    """Given a datset or snapshot id, table name, and entity type {dataset,snapshot}, retrieve its fully qualified BQ table name"""
    if entity_type == 'dataset':
        access_info = get_dataset_access_info(entity_id)
    elif entity_type == 'snapshot':
        access_info = get_snapshot_access_info(entity_id)

    project_id = access_info['accessInformation']['bigQuery']['projectId']
    tables = access_info['accessInformation']['bigQuery']['tables']

    # pull out desired table
    table_fq = None  # fq = fully qualified name, i.e. project.dataset.table
    for table_info in tables:
        if table_info['name'] == table_name:
            table_fq = table_info['qualifiedName'] 
    
    return table_fq


def rename_etype(original_etype, new_etype):
    """Rename PFB handoff tables with `anvil_` prefix."""
    
    uri = f"https://rawls.dsde-prod.broadinstitute.org/api/workspaces/{ws_project}/{ws_name}/entityTypes/{original_etype}"
    
    headers = {"Authorization": "Bearer " + get_access_token(), "accept": "*/*", "Content-Type": "application/json"}
    
    # capture response from API and parse out status code
    d = {"newName": new_etype}
    data = json.dumps(d)
    response = requests.patch(uri, headers=headers, data=data)
    
    status_code = response.status_code
    
    if status_code != 204:
        print(f"Warning: Renaming table from {original_etype} to {new_etype} failed. See error for details:\n")
        print(response.text)
        return status_code, response.text
    
    print(f"Successfully renamed table {original_etype} to {new_etype}.")
    return status_code, response.text
    
    
def create_data_table(entities_tsv):
    """Create a Terra data table given a Terra load tsv."""
    response = fapi.upload_entities_tsv(ws_project, ws_name, entities_tsv, model='flexible')
    
    if response.status_code not in [200, 202]:
        print(f"Loading {entities_tsv} to Terra workspace failed.\n")
        print(response.text)

    print(f"Finished loading {entities_tsv} to Terra workspace.")

        
def group_list(input_list, group_column, entity_name):
    """Group data by their source data table names."""
    
    # create df grouping by input column value
    grouped_df = pd.DataFrame(input_list).groupby(group_column).agg(list)
    
    for index, row in grouped_df.iterrows():
        print(index)
        group_dict = row.to_dict()
        group_df = pd.DataFrame(group_dict)
        
        if index == "file_inventory":
            original_col = "file_id"
            etype_name = "entity:file_inventory_id"
        elif index == "workspace_attributes":
            original_col = "datarepo_row_id"
            etype_name = "entity:workspace_attributes_id"
        else:
            original_col = f"{index}_id"
            etype_name = f"entity:{index}_id"
            
        # rename the id column with entity:[]_id and move to first column
        group_df = group_df.rename(columns={original_col: etype_name})
        
        first_column = group_df.pop(etype_name)
        group_df.insert(0, etype_name, first_column)
        
        filename = write_df_to_tsv(group_df, index)
        create_data_table(filename)
    
    
def write_df_to_tsv(input_df, entity_name):
    """Create a Terra load tsv given a list of dictionaries."""
    
    outfile_name = f"{entity_name}.tsv"

    # rename the first column to have a new entity_name (entity:entity_name_combined:id)
    input_df.to_csv(outfile_name, sep='\t', index=False)
    
    print(f"Finished writing {entity_name} to Terra load file: {outfile_name} \n")
    return outfile_name

    
def get_nfs_data(entity_data):
    """Return non findability subset data mapping to findability subset inputs."""

    nfs = [] # holds list of dictionaries - each dict = single row of NON-findability data
    
    for index, row in entity_data.iterrows():
        # dictionary of findability subset values for a single row
        fs_dict = row.to_dict()
        src_snapshot_id = row["pfb:source_datarepo_snapshot_id"]
        # TODO: handle what to do if the source datarepo row ids have more than 1 source repo id
        src_drr_ids = row["pfb:source_datarepo_row_ids"][0].split(":")[1]
        src_table_name = row["pfb:source_datarepo_row_ids"][0].split(":")[0]
        fq_src_table_name = get_fq_table(src_snapshot_id, src_table_name, entity_type='snapshot')

        print(f"Extracting non-findability subset data for source datarepo_row_id: {src_drr_ids}")
        
        query = f"""SELECT * FROM `{fq_src_table_name}` WHERE datarepo_row_id = '{src_drr_ids}'"""
        results = get_query_results(query)

        # dictionary of NON-findability subset values for a single row
        nfs_dict = results.to_dict("records")[0] # convert results df to a dictionary without index value

        # if any of the dictionary keys (table column names) have Terra reserved names, rename
        # file_inventory table in snapshot has `name` column and fails to load to Terra
        # renaming it to make terra load table work without failure
        if nfs_dict.get('name'):
            nfs_dict["file_name"] = nfs_dict.pop("name")
        
        # add the source table name into dictionary to organize into original workspace table structure
        nfs_dict["source_table_name"] = src_table_name
        
        # TODO: don't combine nfs with fs data, keep in separate tables
        # updated the findability subset dictionary with its non-findability subset data
#         fs_dict.update(nfs_dict)
        # append the combined fs and nfs dictionary to a list
        nfs.append(nfs_dict)
        
        print(f"Finished extracting non-findability subset data: {src_drr_ids} \n\n")

    return nfs

    
def get_ws_nfs_data(ws_project, ws_name):
    """For each entity in the workspace, create combined findability and non-findability subset tables."""
    
    # gets list of single entity types in workspace. (Shift + Enter) to execute.
    
    # API call to get all entity types in workspace
    res_etypes = fapi.list_entity_types(ws_project, ws_name)
    dict_all_etypes = json.loads(res_etypes.text)

    # get non-set entities and add to list
    # the unique ID of any single entity is not modified so sets should remain the same
    single_etypes_list = []
    single_etypes_list = [key for key in dict_all_etypes.keys() if not key.endswith("_set")]

    print(f"List of entity types that will be updated, if applicable:")
    print('\n'.join(['\t' * 7 + c for c in single_etypes_list]))
    
    for etype in single_etypes_list:
        print(f"Starting: {etype}")
        # rename original etype with `anvil_` prefix to match TDR
        print(f"Renaming {etype} to anvil_{etype}.")
        renamed_etype = f"anvil_{etype}"
        status_code, response = rename_etype(etype, renamed_etype)
              
        response = pd.read_csv(StringIO(fapi.get_entities_tsv(ws_project, ws_name, renamed_etype, model='flexible').text), sep='\t')
        # set column of source datarepo_row_ids to type array (come in as string originally)
        response['pfb:source_datarepo_row_ids'] = response['pfb:source_datarepo_row_ids'].map(ast.literal_eval)

        nfs_data_list = get_nfs_data(response)
#         nfs_data_list = get_nfs_data(response.head(5))
        # combined_data_list contains dictionaries - each dict contains source_table_name
        # organize the list items by source_table_name values and then create tsv files and ingest into Terra
        df = group_list(nfs_data_list, "source_table_name", etype)

# %%
# RUN FUNCTION
get_ws_nfs_data(ws_project, ws_name)
# Out:
# List of entity types that will be updated, if applicable:
# 							activities
# 							donors
# 							files
# 							datasets
# 							biosamples
# Starting: activities
# Renaming activities to anvil_activities.
# Successfully renamed table activities to anvil_activities.
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 96c4b433-2c60-433f-9596-2169a342d111
# Finished extracting non-findability subset data: 96c4b433-2c60-433f-9596-2169a342d111
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 812ac0b4-7ed4-49a1-bd8d-9d2e79e520b1
# Finished extracting non-findability subset data: 812ac0b4-7ed4-49a1-bd8d-9d2e79e520b1
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 7e7c2e23-8e56-4820-8ce0-cd5235b308e3
# Finished extracting non-findability subset data: 7e7c2e23-8e56-4820-8ce0-cd5235b308e3
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: af8129fd-bb12-4fcc-838a-35d7ae3064f2
# Finished extracting non-findability subset data: af8129fd-bb12-4fcc-838a-35d7ae3064f2
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: d47fa079-9f48-4cf4-9f00-4558660c1737
# Finished extracting non-findability subset data: d47fa079-9f48-4cf4-9f00-4558660c1737
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 1fd52804-0215-4af2-a730-fd5fe4d2d72b
# Finished extracting non-findability subset data: 1fd52804-0215-4af2-a730-fd5fe4d2d72b
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 9bb1b209-1ecf-4888-a9bf-d9f427152ce0
# Finished extracting non-findability subset data: 9bb1b209-1ecf-4888-a9bf-d9f427152ce0
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 673ba5ab-9417-4742-89bd-8d96c04fec98
# Finished extracting non-findability subset data: 673ba5ab-9417-4742-89bd-8d96c04fec98
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 386146c5-9e66-4c0d-b9df-24fb55975a80
# Finished extracting non-findability subset data: 386146c5-9e66-4c0d-b9df-24fb55975a80
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 32e37f8c-c90d-47b9-91d1-4edc3c0ae51e
# Finished extracting non-findability subset data: 32e37f8c-c90d-47b9-91d1-4edc3c0ae51e
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: e1768d2b-d25f-48b6-8e4d-af83d30feddb
# Finished extracting non-findability subset data: e1768d2b-d25f-48b6-8e4d-af83d30feddb
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: ac3386c5-f6a8-4929-b1c9-2376e55db0e5
# Finished extracting non-findability subset data: ac3386c5-f6a8-4929-b1c9-2376e55db0e5
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 728f3956-508c-483c-bc29-ce86927e1cea
# Finished extracting non-findability subset data: 728f3956-508c-483c-bc29-ce86927e1cea
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 7a5a648e-dc30-43a2-bad7-07267ea3f6ab
# Finished extracting non-findability subset data: 7a5a648e-dc30-43a2-bad7-07267ea3f6ab
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 8ec031b2-1c05-43dd-b5e5-04d88c79075a
# Finished extracting non-findability subset data: 8ec031b2-1c05-43dd-b5e5-04d88c79075a
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 6794c527-1343-4a1c-b303-c2c5deedf60a
# Finished extracting non-findability subset data: 6794c527-1343-4a1c-b303-c2c5deedf60a
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: a1b1ccf4-04aa-4cd8-ab57-2849470e9660
# Finished extracting non-findability subset data: a1b1ccf4-04aa-4cd8-ab57-2849470e9660
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 9f4d2e3b-50ab-4fb8-97b1-1bf827c6a539
# Finished extracting non-findability subset data: 9f4d2e3b-50ab-4fb8-97b1-1bf827c6a539
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: b6c52ff1-665c-4fc4-8374-8882db8cf305
# Finished extracting non-findability subset data: b6c52ff1-665c-4fc4-8374-8882db8cf305
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 76ddc2ef-f020-4636-8c2b-5e655f07d67d
# Finished extracting non-findability subset data: 76ddc2ef-f020-4636-8c2b-5e655f07d67d
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: ac05b826-f4cd-4bb3-b32b-477a94b2565a
# Finished extracting non-findability subset data: ac05b826-f4cd-4bb3-b32b-477a94b2565a
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: e8b98afa-8595-46d2-a47d-ad6dbac10ea3
# Finished extracting non-findability subset data: e8b98afa-8595-46d2-a47d-ad6dbac10ea3
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: ce994dc5-4ba6-4e0d-86b4-a933539116aa
# Finished extracting non-findability subset data: ce994dc5-4ba6-4e0d-86b4-a933539116aa
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: e449fc84-e73a-4c0e-a0bb-94f83898f82f
# Finished extracting non-findability subset data: e449fc84-e73a-4c0e-a0bb-94f83898f82f
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 8ab1c076-62aa-4689-a43e-3870fec358b5
# Finished extracting non-findability subset data: 8ab1c076-62aa-4689-a43e-3870fec358b5
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 3e1dba71-2fef-4f98-bf80-14201bf315f7
# Finished extracting non-findability subset data: 3e1dba71-2fef-4f98-bf80-14201bf315f7
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: b676d912-37e5-432d-9182-50f701773ed8
# Finished extracting non-findability subset data: b676d912-37e5-432d-9182-50f701773ed8
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 7d3b1622-d726-49f6-a1f0-c6d4d04fbdf0
# Finished extracting non-findability subset data: 7d3b1622-d726-49f6-a1f0-c6d4d04fbdf0
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 4e6c81f9-e8a3-4861-9ef4-f6f004bd057b
# Finished extracting non-findability subset data: 4e6c81f9-e8a3-4861-9ef4-f6f004bd057b
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: ab6945c5-7b48-45ee-9119-5fd430c1755e
# Finished extracting non-findability subset data: ab6945c5-7b48-45ee-9119-5fd430c1755e
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: c5b223cd-649f-4b54-9dd9-b6158dc9383f
# Finished extracting non-findability subset data: c5b223cd-649f-4b54-9dd9-b6158dc9383f
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: c75cf322-166c-48be-bf50-9607b6bfc9c0
# Finished extracting non-findability subset data: c75cf322-166c-48be-bf50-9607b6bfc9c0
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: f06136eb-8805-47fc-91f6-7b68ee621fe7
# Finished extracting non-findability subset data: f06136eb-8805-47fc-91f6-7b68ee621fe7
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 573f8acb-d23e-46a0-9df5-78dcf595e855
# Finished extracting non-findability subset data: 573f8acb-d23e-46a0-9df5-78dcf595e855
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 11dafe88-468d-4b1e-a563-1d3f22ccbd14
# Finished extracting non-findability subset data: 11dafe88-468d-4b1e-a563-1d3f22ccbd14
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: b261725f-b30d-4569-bf91-7ada128e77c1
# Finished extracting non-findability subset data: b261725f-b30d-4569-bf91-7ada128e77c1
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 5b273506-2650-42f4-ac75-7bc25b60c532
# Finished extracting non-findability subset data: 5b273506-2650-42f4-ac75-7bc25b60c532
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: f0f07ec5-4cb4-40c0-aaec-59fbb17701ea
# Finished extracting non-findability subset data: f0f07ec5-4cb4-40c0-aaec-59fbb17701ea
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 013478ba-105b-4be2-874a-ad7c4e2f1d22
# Finished extracting non-findability subset data: 013478ba-105b-4be2-874a-ad7c4e2f1d22
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 39a3a539-762b-4105-815e-7d2676c49691
# Finished extracting non-findability subset data: 39a3a539-762b-4105-815e-7d2676c49691
#
#
# Successfully retrieved access information for snapshot with snapshotID 5b77f311-6e67-4a1b-b32a-baa9f5742442.
# Extracting non-findability subset data for source datarepo_row_id: f6e711b7-8614-4f55-8aba-9bf25953e0b5
# Finished extracting non-findability subset data: f6e711b7-8614-4f55-8aba-9bf25953e0b5
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 31fed3ae-f39c-4874-abd9-1d9aa44df5a9
# Finished extracting non-findability subset data: 31fed3ae-f39c-4874-abd9-1d9aa44df5a9
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: d8d7ec50-3c0f-4501-b8ba-0f3d6024bcef
# Finished extracting non-findability subset data: d8d7ec50-3c0f-4501-b8ba-0f3d6024bcef
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 8d17b059-90ee-4dfe-8de2-5eaae1fe9b2a
# Finished extracting non-findability subset data: 8d17b059-90ee-4dfe-8de2-5eaae1fe9b2a
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 02dda6a7-9ac5-4071-bbf9-54d5e322e169
# Finished extracting non-findability subset data: 02dda6a7-9ac5-4071-bbf9-54d5e322e169
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: bfc5ceb1-583b-4c05-ba5e-c5285b5ed2ae
# Finished extracting non-findability subset data: bfc5ceb1-583b-4c05-ba5e-c5285b5ed2ae
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: bb840ea4-3b76-439e-b9db-37ecfad6bca5
# Finished extracting non-findability subset data: bb840ea4-3b76-439e-b9db-37ecfad6bca5
#
#
# Successfully retrieved access information for snapshot with snapshotID 5b77f311-6e67-4a1b-b32a-baa9f5742442.
# Extracting non-findability subset data for source datarepo_row_id: f171024c-a01f-438f-a671-db5fbb7c5304
# Finished extracting non-findability subset data: f171024c-a01f-438f-a671-db5fbb7c5304
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 8b63a607-fa8b-48ca-b94d-2bddbb46344c
# Finished extracting non-findability subset data: 8b63a607-fa8b-48ca-b94d-2bddbb46344c
#
#
# Successfully retrieved access information for snapshot with snapshotID 5b77f311-6e67-4a1b-b32a-baa9f5742442.
# Extracting non-findability subset data for source datarepo_row_id: 80d68d8a-179b-4e95-9d48-02a7c95edffc
# Finished extracting non-findability subset data: 80d68d8a-179b-4e95-9d48-02a7c95edffc
#
#
# Successfully retrieved access information for snapshot with snapshotID 5b77f311-6e67-4a1b-b32a-baa9f5742442.
# Extracting non-findability subset data for source datarepo_row_id: a6c663c7-6f26-4ed2-af9d-48e9c709a22b
# Finished extracting non-findability subset data: a6c663c7-6f26-4ed2-af9d-48e9c709a22b
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: fbf597db-5c88-47c9-9778-f704cc675f44
# Finished extracting non-findability subset data: fbf597db-5c88-47c9-9778-f704cc675f44
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 2a4f8832-bf43-4c30-87ac-e685f10d5c66
# Finished extracting non-findability subset data: 2a4f8832-bf43-4c30-87ac-e685f10d5c66
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 098b9e69-2963-4ffc-8b14-28f1139bc57f
# Finished extracting non-findability subset data: 098b9e69-2963-4ffc-8b14-28f1139bc57f
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 08616153-d19e-443f-9e50-696dbfea610d
# Finished extracting non-findability subset data: 08616153-d19e-443f-9e50-696dbfea610d
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 9fc6b50c-9815-4a6d-94cf-252592788770
# Finished extracting non-findability subset data: 9fc6b50c-9815-4a6d-94cf-252592788770
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 213c2ee4-6045-455d-8438-ad08dbdc7f9a
# Finished extracting non-findability subset data: 213c2ee4-6045-455d-8438-ad08dbdc7f9a
#
#
# Successfully retrieved access information for snapshot with snapshotID 5b77f311-6e67-4a1b-b32a-baa9f5742442.
# Extracting non-findability subset data for source datarepo_row_id: d4f6c0c4-1e11-438e-8218-cfea63b8b051
# Finished extracting non-findability subset data: d4f6c0c4-1e11-438e-8218-cfea63b8b051
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: da4c5b6c-dccf-4abc-aa4a-3968a2d894df
# Finished extracting non-findability subset data: da4c5b6c-dccf-4abc-aa4a-3968a2d894df
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 333e28ee-3d84-4382-b2f0-e605b6342333
# Finished extracting non-findability subset data: 333e28ee-3d84-4382-b2f0-e605b6342333
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 318ad784-20cf-4f0f-9732-847d9f228728
# Finished extracting non-findability subset data: 318ad784-20cf-4f0f-9732-847d9f228728
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: ce15650f-5716-4cba-81dc-528cd8027c3b
# Finished extracting non-findability subset data: ce15650f-5716-4cba-81dc-528cd8027c3b
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 15334b52-e7bb-4d5b-a201-61a91ade89d9
# Finished extracting non-findability subset data: 15334b52-e7bb-4d5b-a201-61a91ade89d9
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 7a9cfbbf-a65c-4343-babb-164835b8349c
# Finished extracting non-findability subset data: 7a9cfbbf-a65c-4343-babb-164835b8349c
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 97f6d3b5-55b4-402a-b8db-b4280a34bea3
# Finished extracting non-findability subset data: 97f6d3b5-55b4-402a-b8db-b4280a34bea3
#
#
# Successfully retrieved access information for snapshot with snapshotID 5b77f311-6e67-4a1b-b32a-baa9f5742442.
# Extracting non-findability subset data for source datarepo_row_id: c6222792-ccf6-48e0-a2f4-b48f48fe389a
# Finished extracting non-findability subset data: c6222792-ccf6-48e0-a2f4-b48f48fe389a
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 54af3740-da98-4bd2-bd13-6fc8aea391ae
# Finished extracting non-findability subset data: 54af3740-da98-4bd2-bd13-6fc8aea391ae
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: d97b9f76-61e6-4a57-bc3b-bbbee9104108
# Finished extracting non-findability subset data: d97b9f76-61e6-4a57-bc3b-bbbee9104108
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 126070ba-89da-471f-ad20-45e74380d073
# Finished extracting non-findability subset data: 126070ba-89da-471f-ad20-45e74380d073
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 4731341c-80e8-42c1-bae8-99f63c721970
# Finished extracting non-findability subset data: 4731341c-80e8-42c1-bae8-99f63c721970
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 6f7b0438-14d3-4b61-a25b-55ca6582f0b4
# Finished extracting non-findability subset data: 6f7b0438-14d3-4b61-a25b-55ca6582f0b4
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 17a6189f-4dff-4066-b350-1fb4a5398167
# Finished extracting non-findability subset data: 17a6189f-4dff-4066-b350-1fb4a5398167
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: bd4f1ced-b196-49a9-8708-a449c296e0bd
# Finished extracting non-findability subset data: bd4f1ced-b196-49a9-8708-a449c296e0bd
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: d9cb2b53-b937-4bcf-ac6b-18ab91c2d965
# Finished extracting non-findability subset data: d9cb2b53-b937-4bcf-ac6b-18ab91c2d965
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 4a5e7fca-6212-42c7-b7e0-02714fbaac68
# Finished extracting non-findability subset data: 4a5e7fca-6212-42c7-b7e0-02714fbaac68
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: e977cddd-8920-4f17-8a3c-c7739f1266dd
# Finished extracting non-findability subset data: e977cddd-8920-4f17-8a3c-c7739f1266dd
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 3ea8adba-4f21-42dd-801e-3e651b8310bc
# Finished extracting non-findability subset data: 3ea8adba-4f21-42dd-801e-3e651b8310bc
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 84d21ae2-e575-44f8-ab7e-cde1d6f280d3
# Finished extracting non-findability subset data: 84d21ae2-e575-44f8-ab7e-cde1d6f280d3
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 6271f7c3-af22-425d-b3f3-c312d248cbee
# Finished extracting non-findability subset data: 6271f7c3-af22-425d-b3f3-c312d248cbee
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 12098d11-fd04-42e9-aeb7-85b6c034a09f
# Finished extracting non-findability subset data: 12098d11-fd04-42e9-aeb7-85b6c034a09f
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 067573d0-e354-4232-bb82-8ce3882744ce
# Finished extracting non-findability subset data: 067573d0-e354-4232-bb82-8ce3882744ce
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: ad331e15-f810-42aa-b37c-6c5501f0e75c
# Finished extracting non-findability subset data: ad331e15-f810-42aa-b37c-6c5501f0e75c
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 7d310917-2a83-4031-a2fe-2078f6d4ff9e
# Finished extracting non-findability subset data: 7d310917-2a83-4031-a2fe-2078f6d4ff9e
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 48ae0de3-edff-4576-9c5f-757d9320993f
# Finished extracting non-findability subset data: 48ae0de3-edff-4576-9c5f-757d9320993f
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 79a1c31c-b357-4578-b27e-21c6ae2d88c6
# Finished extracting non-findability subset data: 79a1c31c-b357-4578-b27e-21c6ae2d88c6
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 26c62292-abf4-41f9-9cdc-baccfb6a9e73
# Finished extracting non-findability subset data: 26c62292-abf4-41f9-9cdc-baccfb6a9e73
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 9305a226-7c44-45ba-a995-f2f13c4218b2
# Finished extracting non-findability subset data: 9305a226-7c44-45ba-a995-f2f13c4218b2
#
#
# Successfully retrieved access information for snapshot with snapshotID 5b77f311-6e67-4a1b-b32a-baa9f5742442.
# Extracting non-findability subset data for source datarepo_row_id: 7eb01efe-58d7-41e0-a932-7bceafd2bf83
# Finished extracting non-findability subset data: 7eb01efe-58d7-41e0-a932-7bceafd2bf83
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 3c6d0de8-719a-4f67-b3f9-e138d255d5e8
# Finished extracting non-findability subset data: 3c6d0de8-719a-4f67-b3f9-e138d255d5e8
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 117f6523-ba69-4bb3-983b-ab3f85a7c58f
# Finished extracting non-findability subset data: 117f6523-ba69-4bb3-983b-ab3f85a7c58f
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 113fa56d-fa79-4f30-b82e-ec05e2e7d34f
# Finished extracting non-findability subset data: 113fa56d-fa79-4f30-b82e-ec05e2e7d34f
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 9cfdc3d6-24fa-486d-b76a-0423779258b0
# Finished extracting non-findability subset data: 9cfdc3d6-24fa-486d-b76a-0423779258b0
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: b5646fc9-96a2-4e1f-aa21-dd5655ddb2e8
# Finished extracting non-findability subset data: b5646fc9-96a2-4e1f-aa21-dd5655ddb2e8
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: b77cb926-5b65-4c03-86cb-33da38318bb6
# Finished extracting non-findability subset data: b77cb926-5b65-4c03-86cb-33da38318bb6
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: fd006c5e-c71a-4479-87d9-9e3d720e541a
# Finished extracting non-findability subset data: fd006c5e-c71a-4479-87d9-9e3d720e541a
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 24b6b4db-5b45-4687-884e-2cbabf3dd9be
# Finished extracting non-findability subset data: 24b6b4db-5b45-4687-884e-2cbabf3dd9be
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 78bf015b-f6e6-4f23-8ee5-a7ff826486db
# Finished extracting non-findability subset data: 78bf015b-f6e6-4f23-8ee5-a7ff826486db
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: abe9e770-5668-48eb-9942-50291b17fce5
# Finished extracting non-findability subset data: abe9e770-5668-48eb-9942-50291b17fce5
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 0d196d9c-d872-4a7c-865e-a5dbdd40e06c
# Finished extracting non-findability subset data: 0d196d9c-d872-4a7c-865e-a5dbdd40e06c
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 22c5e98a-1a92-4be8-a67b-f73cc935fb0c
# Finished extracting non-findability subset data: 22c5e98a-1a92-4be8-a67b-f73cc935fb0c
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: b87b1163-1ccd-4804-907d-86c4d2cc113d
# Finished extracting non-findability subset data: b87b1163-1ccd-4804-907d-86c4d2cc113d
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 171874a9-feb0-4019-a5ab-058072ccae35
# Finished extracting non-findability subset data: 171874a9-feb0-4019-a5ab-058072ccae35
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 83d4eaff-1076-4ed4-bb38-c8d576679dd9
# Finished extracting non-findability subset data: 83d4eaff-1076-4ed4-bb38-c8d576679dd9
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: dcc988d5-ca31-433f-be21-a1b862fb4c8d
# Finished extracting non-findability subset data: dcc988d5-ca31-433f-be21-a1b862fb4c8d
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: b775f0c5-f7ae-43b8-9cc9-af8dc975ae11
# Finished extracting non-findability subset data: b775f0c5-f7ae-43b8-9cc9-af8dc975ae11
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 9a251c99-328f-4933-a3ce-aec5f80a38e9
# Finished extracting non-findability subset data: 9a251c99-328f-4933-a3ce-aec5f80a38e9
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 573b3bab-8496-4726-a06d-fa3f3a9de984
# Finished extracting non-findability subset data: 573b3bab-8496-4726-a06d-fa3f3a9de984
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 62383f7d-1c4f-4a99-b3ec-cef983a7bf17
# Finished extracting non-findability subset data: 62383f7d-1c4f-4a99-b3ec-cef983a7bf17
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 12e37e0d-fed2-41d3-9b6a-ba69c8be3a52
# Finished extracting non-findability subset data: 12e37e0d-fed2-41d3-9b6a-ba69c8be3a52
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: fd18aae8-59ca-4eb3-a6cb-701cd33bf255
# Finished extracting non-findability subset data: fd18aae8-59ca-4eb3-a6cb-701cd33bf255
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 47e009e8-325a-4421-a25c-77e633899918
# Finished extracting non-findability subset data: 47e009e8-325a-4421-a25c-77e633899918
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: c46bee8e-7eb5-4c1f-906d-93fc19042bfc
# Finished extracting non-findability subset data: c46bee8e-7eb5-4c1f-906d-93fc19042bfc
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: f930f39c-f110-4837-8f9c-8218ac8d64fb
# Finished extracting non-findability subset data: f930f39c-f110-4837-8f9c-8218ac8d64fb
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 26249b4d-0bd5-4629-b054-cb0081064e4e
# Finished extracting non-findability subset data: 26249b4d-0bd5-4629-b054-cb0081064e4e
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 59945839-2dca-49df-9ecb-ea1a4559984c
# Finished extracting non-findability subset data: 59945839-2dca-49df-9ecb-ea1a4559984c
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: a3964c2d-3ed5-4a94-a556-a3d6d2d6e694
# Finished extracting non-findability subset data: a3964c2d-3ed5-4a94-a556-a3d6d2d6e694
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 0f7de798-3685-4f2c-803e-25b6e6816aea
# Finished extracting non-findability subset data: 0f7de798-3685-4f2c-803e-25b6e6816aea
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 65afe772-01a5-4b0b-ba76-1df07a0188d4
# Finished extracting non-findability subset data: 65afe772-01a5-4b0b-ba76-1df07a0188d4
#
#
# Successfully retrieved access information for snapshot with snapshotID 5b77f311-6e67-4a1b-b32a-baa9f5742442.
# Extracting non-findability subset data for source datarepo_row_id: 9e6f2845-ccc8-4691-b7a5-35571d97710c
# Finished extracting non-findability subset data: 9e6f2845-ccc8-4691-b7a5-35571d97710c
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 0b06b66d-8552-49ec-9e28-a910cbec5cc9
# Finished extracting non-findability subset data: 0b06b66d-8552-49ec-9e28-a910cbec5cc9
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: d7127c29-dde2-4c6d-8a47-27b6e0a91680
# Finished extracting non-findability subset data: d7127c29-dde2-4c6d-8a47-27b6e0a91680
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: dde535fc-beaf-4469-8679-1343abbe7549
# Finished extracting non-findability subset data: dde535fc-beaf-4469-8679-1343abbe7549
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: aac8962c-0861-4337-97e5-276c64aaeb6f
# Finished extracting non-findability subset data: aac8962c-0861-4337-97e5-276c64aaeb6f
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: dc6801c6-0ad0-48aa-9eb5-2b7197e56ac9
# Finished extracting non-findability subset data: dc6801c6-0ad0-48aa-9eb5-2b7197e56ac9
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 3ee3fb1b-dac9-48e0-bc61-bfcb93f4ed42
# Finished extracting non-findability subset data: 3ee3fb1b-dac9-48e0-bc61-bfcb93f4ed42
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 8e73260c-7c99-4067-ac05-20ce430a5cb8
# Finished extracting non-findability subset data: 8e73260c-7c99-4067-ac05-20ce430a5cb8
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 625cd31f-e0d5-401b-b8f9-fd6286f69554
# Finished extracting non-findability subset data: 625cd31f-e0d5-401b-b8f9-fd6286f69554
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 70138991-0507-4b27-99da-f8ff957a119b
# Finished extracting non-findability subset data: 70138991-0507-4b27-99da-f8ff957a119b
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: e6a3ae89-8d20-4552-bae9-9bdeac212a4e
# Finished extracting non-findability subset data: e6a3ae89-8d20-4552-bae9-9bdeac212a4e
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 7ec752e4-c7c5-41e3-948a-3d9406ad6422
# Finished extracting non-findability subset data: 7ec752e4-c7c5-41e3-948a-3d9406ad6422
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 5cef2173-207a-4ebe-bcb8-524daf20f14b
# Finished extracting non-findability subset data: 5cef2173-207a-4ebe-bcb8-524daf20f14b
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 5c85b891-cb54-475b-a80b-32ea44a03cfd
# Finished extracting non-findability subset data: 5c85b891-cb54-475b-a80b-32ea44a03cfd
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: c6936621-3b87-4276-a72a-db3bc7f2a7ae
# Finished extracting non-findability subset data: c6936621-3b87-4276-a72a-db3bc7f2a7ae
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: a579f48d-be76-4146-befd-b2b1a217c113
# Finished extracting non-findability subset data: a579f48d-be76-4146-befd-b2b1a217c113
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 659d83e4-374a-42e9-89a5-6f396943f7c9
# Finished extracting non-findability subset data: 659d83e4-374a-42e9-89a5-6f396943f7c9
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: a210c2ac-037d-481c-acf6-bb70c13bcc12
# Finished extracting non-findability subset data: a210c2ac-037d-481c-acf6-bb70c13bcc12
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: f9e70781-ffd6-46dd-a92a-733ac060cb08
# Finished extracting non-findability subset data: f9e70781-ffd6-46dd-a92a-733ac060cb08
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 21b51f5f-0e90-42a3-89a6-791793719467
# Finished extracting non-findability subset data: 21b51f5f-0e90-42a3-89a6-791793719467
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 109ebbb8-aa52-4c72-9ab6-eecabc7d82c9
# Finished extracting non-findability subset data: 109ebbb8-aa52-4c72-9ab6-eecabc7d82c9
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: dbacc98d-e44e-4dac-b8fb-d9089debc407
# Finished extracting non-findability subset data: dbacc98d-e44e-4dac-b8fb-d9089debc407
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 4b83934c-c381-46cc-967a-ce987ec3d901
# Finished extracting non-findability subset data: 4b83934c-c381-46cc-967a-ce987ec3d901
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 40b1aebb-9ea9-4919-aa41-22105360d267
# Finished extracting non-findability subset data: 40b1aebb-9ea9-4919-aa41-22105360d267
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 50667243-00bf-4616-abb2-e942a5a880b2
# Finished extracting non-findability subset data: 50667243-00bf-4616-abb2-e942a5a880b2
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 823aedd3-3aff-470f-9e1c-34cdab3f3230
# Finished extracting non-findability subset data: 823aedd3-3aff-470f-9e1c-34cdab3f3230
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 94f45c82-c7ca-4248-9905-4f98879f697e
# Finished extracting non-findability subset data: 94f45c82-c7ca-4248-9905-4f98879f697e
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 96827760-ce7b-400a-ae35-1eb6133bbefc
# Finished extracting non-findability subset data: 96827760-ce7b-400a-ae35-1eb6133bbefc
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 44417381-789e-4515-9b43-f33dec4495cd
# Finished extracting non-findability subset data: 44417381-789e-4515-9b43-f33dec4495cd
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: f519a8a8-d756-4bfb-bc3b-af1e42de74b7
# Finished extracting non-findability subset data: f519a8a8-d756-4bfb-bc3b-af1e42de74b7
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: c7bce30d-4164-4e67-bb14-5599cdadb01d
# Finished extracting non-findability subset data: c7bce30d-4164-4e67-bb14-5599cdadb01d
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 8942a1b0-8726-4a50-b85a-500ab7d793fc
# Finished extracting non-findability subset data: 8942a1b0-8726-4a50-b85a-500ab7d793fc
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: fe32a372-546d-4cb9-bcb1-366d95507983
# Finished extracting non-findability subset data: fe32a372-546d-4cb9-bcb1-366d95507983
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: bbd6490b-1b63-4a9f-a102-3d2b1e3660c5
# Finished extracting non-findability subset data: bbd6490b-1b63-4a9f-a102-3d2b1e3660c5
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 0840ccab-5fb6-47c5-a060-0865749a5a67
# Finished extracting non-findability subset data: 0840ccab-5fb6-47c5-a060-0865749a5a67
#
#
# Successfully retrieved access information for snapshot with snapshotID 5b77f311-6e67-4a1b-b32a-baa9f5742442.
# Extracting non-findability subset data for source datarepo_row_id: 84b3cc21-36dc-4be0-a276-5bd7c01b4ec4
# Finished extracting non-findability subset data: 84b3cc21-36dc-4be0-a276-5bd7c01b4ec4
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 4058c3b2-a11c-4891-9437-3273ef531176
# Finished extracting non-findability subset data: 4058c3b2-a11c-4891-9437-3273ef531176
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 6288676e-978e-462c-a97a-ac23ce5c9344
# Finished extracting non-findability subset data: 6288676e-978e-462c-a97a-ac23ce5c9344
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 32c6f4a9-d95c-4bd8-a90d-47a022f02961
# Finished extracting non-findability subset data: 32c6f4a9-d95c-4bd8-a90d-47a022f02961
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: f6ea95fc-5ea1-46a5-90f4-23b19e408df3
# Finished extracting non-findability subset data: f6ea95fc-5ea1-46a5-90f4-23b19e408df3
#
#
# ...
# Finished extracting non-findability subset data: 4f62a46c-b428-4326-aba9-2caedc06308f
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 31e62564-d11d-40e8-9577-a518f3bbef3d
# Finished extracting non-findability subset data: 31e62564-d11d-40e8-9577-a518f3bbef3d
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 9dbcb30d-6043-40c6-b168-64547bb12e2f
# Finished extracting non-findability subset data: 9dbcb30d-6043-40c6-b168-64547bb12e2f
#
#
# Successfully retrieved access information for snapshot with snapshotID 5b77f311-6e67-4a1b-b32a-baa9f5742442.
# Extracting non-findability subset data for source datarepo_row_id: 68cfda28-9897-4de2-b9ad-434d301da173
# Finished extracting non-findability subset data: 68cfda28-9897-4de2-b9ad-434d301da173
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 3d78f747-98be-4f95-b737-93f480d89099
# Finished extracting non-findability subset data: 3d78f747-98be-4f95-b737-93f480d89099
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: de936a6b-78fa-4574-8b86-11a0d5cd9b9d
# Finished extracting non-findability subset data: de936a6b-78fa-4574-8b86-11a0d5cd9b9d
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 6fbeb193-99b5-48b3-95e1-af2f1af95d87
# Finished extracting non-findability subset data: 6fbeb193-99b5-48b3-95e1-af2f1af95d87
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 357eb072-5c9f-4332-8626-2fc7c6f0f455
# Finished extracting non-findability subset data: 357eb072-5c9f-4332-8626-2fc7c6f0f455
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 2babad1b-b6d6-49b3-86c5-8f664086faa7
# Finished extracting non-findability subset data: 2babad1b-b6d6-49b3-86c5-8f664086faa7
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 354cad77-52c3-4b30-859a-98bd9323d643
# Finished extracting non-findability subset data: 354cad77-52c3-4b30-859a-98bd9323d643
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: ee36c0f4-ceb8-4c8c-9fb4-abb3d2021841
# Finished extracting non-findability subset data: ee36c0f4-ceb8-4c8c-9fb4-abb3d2021841
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 27bf78f5-5a47-49b0-af3b-a069b35cc2f8
# Finished extracting non-findability subset data: 27bf78f5-5a47-49b0-af3b-a069b35cc2f8
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: ca123a19-569b-493e-bbc2-d9dac1ce9a31
# Finished extracting non-findability subset data: ca123a19-569b-493e-bbc2-d9dac1ce9a31
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 5f88eb03-a90c-4667-8b88-9266e15797dc
# Finished extracting non-findability subset data: 5f88eb03-a90c-4667-8b88-9266e15797dc
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: e73a39bc-8d95-4edc-bcae-c4c5249b904d
# Finished extracting non-findability subset data: e73a39bc-8d95-4edc-bcae-c4c5249b904d
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 6190ccac-45fc-43d5-b796-05218ca5d958
# Finished extracting non-findability subset data: 6190ccac-45fc-43d5-b796-05218ca5d958
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: acfbb08e-6ed4-4aba-9681-8c3407358293
# Finished extracting non-findability subset data: acfbb08e-6ed4-4aba-9681-8c3407358293
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: f7dc5064-bc0a-40a6-ae6e-dc9bed75a515
# Finished extracting non-findability subset data: f7dc5064-bc0a-40a6-ae6e-dc9bed75a515
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 2acc1e10-2dc7-4b82-8f77-be68f6663309
# Finished extracting non-findability subset data: 2acc1e10-2dc7-4b82-8f77-be68f6663309
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 283fa066-47ea-4ae0-92c6-a8933e41f093
# Finished extracting non-findability subset data: 283fa066-47ea-4ae0-92c6-a8933e41f093
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: dc688a35-1136-46ce-9eb6-ccacaf02e8db
# Finished extracting non-findability subset data: dc688a35-1136-46ce-9eb6-ccacaf02e8db
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 340796d9-c361-40a6-a0c9-b42a93855782
# Finished extracting non-findability subset data: 340796d9-c361-40a6-a0c9-b42a93855782
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 8d9c046c-5304-49e2-a5f8-4db2618ac023
# Finished extracting non-findability subset data: 8d9c046c-5304-49e2-a5f8-4db2618ac023
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 3736d8b7-ced1-4b1f-9c51-d8244f4333de
# Finished extracting non-findability subset data: 3736d8b7-ced1-4b1f-9c51-d8244f4333de
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 307b2bd4-2e50-4f07-9e55-558785d23f34
# Finished extracting non-findability subset data: 307b2bd4-2e50-4f07-9e55-558785d23f34
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 1e8680d6-4f9b-4f9f-ac68-9b100c8fde16
# Finished extracting non-findability subset data: 1e8680d6-4f9b-4f9f-ac68-9b100c8fde16
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 65378e7b-ce2f-4ebb-86b2-e1b67d55c4e9
# Finished extracting non-findability subset data: 65378e7b-ce2f-4ebb-86b2-e1b67d55c4e9
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: f15c909c-5ff5-41dd-a4ba-e34ce85e1b4d
# Finished extracting non-findability subset data: f15c909c-5ff5-41dd-a4ba-e34ce85e1b4d
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 602a161e-486d-415f-9bbd-58fdc51aa8d9
# Finished extracting non-findability subset data: 602a161e-486d-415f-9bbd-58fdc51aa8d9
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 9c974fd1-5525-40b4-8652-1d310fa5a2cd
# Finished extracting non-findability subset data: 9c974fd1-5525-40b4-8652-1d310fa5a2cd
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: e884ee06-feb6-463d-830f-4576ffb247ef
# Finished extracting non-findability subset data: e884ee06-feb6-463d-830f-4576ffb247ef
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 62ab3f45-63ea-401d-afd6-710ef10e90d1
# Finished extracting non-findability subset data: 62ab3f45-63ea-401d-afd6-710ef10e90d1
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 8663aa26-21cf-4bdb-9938-f436b77113df
# Finished extracting non-findability subset data: 8663aa26-21cf-4bdb-9938-f436b77113df
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 38576875-f650-44b3-adee-5d278ec48069
# Finished extracting non-findability subset data: 38576875-f650-44b3-adee-5d278ec48069
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: a02bf34b-baf6-4a8b-9de4-67fc7c43a33d
# Finished extracting non-findability subset data: a02bf34b-baf6-4a8b-9de4-67fc7c43a33d
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: c075a7f3-971d-48e8-b28d-0e739d5564e9
# Finished extracting non-findability subset data: c075a7f3-971d-48e8-b28d-0e739d5564e9
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 2e03182f-d55d-4de4-90bb-36c8549f435c
# Finished extracting non-findability subset data: 2e03182f-d55d-4de4-90bb-36c8549f435c
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: c048ed9c-b4e8-4fb1-a63e-77759ef636bc
# Finished extracting non-findability subset data: c048ed9c-b4e8-4fb1-a63e-77759ef636bc
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 9643f02e-80eb-441f-a217-a73de6db61f6
# Finished extracting non-findability subset data: 9643f02e-80eb-441f-a217-a73de6db61f6
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: a868f569-e148-44a5-a5c2-4368c7ad1401
# Finished extracting non-findability subset data: a868f569-e148-44a5-a5c2-4368c7ad1401
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 287a6e2f-452d-4ef6-9ae1-769a28502141
# Finished extracting non-findability subset data: 287a6e2f-452d-4ef6-9ae1-769a28502141
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: f5be5c03-98ed-47b5-b54f-b24f58df9e77
# Finished extracting non-findability subset data: f5be5c03-98ed-47b5-b54f-b24f58df9e77
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 008b3d4e-0f4a-43d0-8af0-23a35a691660
# Finished extracting non-findability subset data: 008b3d4e-0f4a-43d0-8af0-23a35a691660
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: d78585d5-40ee-4677-a799-2829249e94ac
# Finished extracting non-findability subset data: d78585d5-40ee-4677-a799-2829249e94ac
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: d084fd8e-ccde-4082-baf9-7e6a399205de
# Finished extracting non-findability subset data: d084fd8e-ccde-4082-baf9-7e6a399205de
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: b7c5b808-a148-4bf8-ab31-3214dcf7b56d
# Finished extracting non-findability subset data: b7c5b808-a148-4bf8-ab31-3214dcf7b56d
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 5b6cebfe-643d-4fb7-843a-dfdd6e188669
# Finished extracting non-findability subset data: 5b6cebfe-643d-4fb7-843a-dfdd6e188669
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 51162f19-38ab-4e28-b6d0-cc6fb2239daa
# Finished extracting non-findability subset data: 51162f19-38ab-4e28-b6d0-cc6fb2239daa
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 5d330936-44a0-4bff-bbe3-423124f2667b
# Finished extracting non-findability subset data: 5d330936-44a0-4bff-bbe3-423124f2667b
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 54dd0b1d-3b07-46c6-ab90-215b01c6bc7f
# Finished extracting non-findability subset data: 54dd0b1d-3b07-46c6-ab90-215b01c6bc7f
#
#
# Successfully retrieved access information for snapshot with snapshotID e6412f80-f150-4212-a4a7-bac6f1a1fb33.
# Extracting non-findability subset data for source datarepo_row_id: 2f678373-a47e-497e-9a14-68dc5711ef41
# Finished extracting non-findability subset data: 2f678373-a47e-497e-9a14-68dc5711ef41
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: b1ba2439-7daf-47f8-b295-bfe523b61b1c
# Finished extracting non-findability subset data: b1ba2439-7daf-47f8-b295-bfe523b61b1c
#
#
# Successfully retrieved access information for snapshot with snapshotID a6c7c091-834f-498d-bce2-211b7557f8f9.
# Extracting non-findability subset data for source datarepo_row_id: 53be9ef3-805b-454e-b984-948926847add
# Finished extracting non-findability subset data: 53be9ef3-805b-454e-b984-948926847add
#
#
# sample
# Finished writing sample to Terra load file: sample.tsv
#
# Finished loading sample.tsv to Terra workspace.

# %%
# !gsutil cp *.tsv $ws_bucket

# %%
# TODO: handle what happens if src data repo row ids list has more than one source data repo row id
# TODO: what is user flow? do they pass in a snapshots worth of data or do we run everything in the data tables each time
